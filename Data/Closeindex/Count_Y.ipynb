# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# 提取每个月出现在表格中的第一天，并清洗数据

# %%
df=pd.read_csv("processed_close_index.csv")
df = df.dropna()
df.set_index('Unnamed: 0', inplace=True)
df.index.name = None
df.columns = pd.to_datetime(df.columns)
dates = df.columns.tolist()
processed_months = set()

# 初始化列表来保存每个月的第一天
first_days = []

# 遍历排序后的日期列表
for date in dates:
    month_key = (date.year, date.month)  # 用年和月作为键
    if month_key not in processed_months:
        # 这是第一次遇到这个月，添加到结果列表中
        first_days.append(date)
        # 标记这个月已处理
        processed_months.add(month_key)

# %%
process_df = df[first_days]
process_df.columns = process_df.columns.strftime('%Y-%m')
process_df.to_csv("process_data.csv")

# %% [markdown]
# 查看成长率

# %%
result = (process_df - process_df.shift(axis=1))/process_df.shift(axis=1)
result = result.drop(result.columns[0],axis=1)
result
# Out:
#                    2007-02-01  2007-03-01  2007-04-02  2007-05-08  2007-06-01  \
# 000015_上证红利          0.124606    0.078604    0.136079    0.330824   -0.006885
# 000052_上证50基本        0.113644    0.033935    0.134974    0.226161    0.015503
# 000053_上证180基本       0.145697    0.070651    0.152275    0.299643    0.001738
# 000128_上证380基本       0.270387    0.136542    0.230318    0.449576   -0.064895
# 000129_上证180波动       0.195205    0.086666    0.171398    0.364166    0.006695
# 000130_上证380波动       0.260729    0.150692    0.214685    0.439102   -0.064412
# 000135_上证180高贝       0.245746    0.114877    0.177604    0.352694   -0.021416
# 000136_上证180低贝       0.175380    0.076764    0.153994    0.327235    0.007896
# 000137_上证380高贝       0.326345    0.125049    0.208794    0.408022   -0.080049
# 000138_上证380低贝       0.275696    0.111540    0.199122    0.363832   -0.040716
# 000803_300波动         0.227758    0.110354    0.175274    0.380434   -0.025011
# ...

# %% [markdown]
# 选取增长率前5的标签1，其余标签为0

# %%
def process2Y(column):
    top_five = column.nlargest(5)
    return column.apply(lambda x: 1 if x in top_five.values else 0)

processed_result = result.apply(process2Y)
processed_result.columns = processed_result.columns.strftime('%Y-%m')
processed_result
# Out:
#                    2007-02  2007-03  2007-04  2007-05  2007-06  2007-07  \
# 000015_上证红利              0        0        0        0        0        0
# 000052_上证50基本            0        0        0        0        0        0
# 000053_上证180基本           0        0        0        0        0        0
# 000128_上证380基本           0        1        1        1        0        0
# 000129_上证180波动           0        0        0        0        0        0
# 000130_上证380波动           0        1        0        1        0        0
# 000135_上证180高贝           0        0        0        0        0        0
# 000136_上证180低贝           0        0        0        0        0        0
# 000137_上证380高贝           1        0        0        0        0        0
# 000138_上证380低贝           1        0        0        0        0        0
# 000803_300波动             0        0        0        0        0        0
# 000804_中证500波动           1        0        1        1        0        0
# ...

# %%
processed_result.to_csv('Count_Y.csv')
